# %%
import sys
from equadratures import polytree
import random
import numpy as np
import scipy.stats as st
import time
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib.lines as mlines
# %matplotlib inline
from copy import deepcopy

# %%
def f(x, noise):
    
    if noise:
        noise = 0.1 * st.norm.rvs(0, 1)
    else:
        noise = 0
    if x < 0.5:
        return 25*(x-0.25)**2 - 1.0625 + noise
    elif x > 0.5:
        return 25*(x-0.75)**2 - 1.0625 + noise
    
def sample():
    X, y = [], []
    for i in range(100):
        x = random.random()    
        X.append(np.array([x]))
        y.append(np.array([f(x, True)]))
    return np.array(X), np.array(y)

X, y = sample()
y = np.reshape(y, (y.shape[0], 1))

tree = polytree.PolyTree(min_samples_leaf=20, logging=True)
#tree = polytree.PolyTree(search="uniform", min_samples_leaf=20, logging=True)
start = time.time()
tree.fit(X, y)
duration = time.time() - start

# %%
tree.log
# Out:
# [{'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.23397719250485727,
#    'loss': 0.06252406600031392,
#    'poly_left': <equadratures.poly.Poly at 0x7ff1284967f0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d7914760>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.24882552519271528,
#    'loss': 0.05786601776967423,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d79148b0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d79342b0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.26952736702290236,
#    'loss': 0.053814385609798496,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d79341c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d79347c0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.27072623743901547,
#    'loss': 0.047891723600372645,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d79391f0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d7939700>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.2904935595707573,
#    'loss': 0.046274590664117744,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d7939730>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58bf160>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.2972591377622116,
#    'loss': 0.04370252915707708,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58bf430>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58bf6a0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3081009660269852,
#    'loss': 0.04499353832148225,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58bd0d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58bd3a0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.31319671161360196,
#    'loss': 0.04397947677440718,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58bd610>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58bdbb0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3166453668608805,
#    'loss': 0.04270156427036797,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58c7550>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58c7580>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.33258854325937126,
#    'loss': 0.04261744251921144,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58c7b20>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58d74c0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3463647536235812,
#    'loss': 0.045345450320095335,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58d74f0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58d7a90>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3704233662191777,
#    'loss': 0.04683142746493535,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58df1c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58df430>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.37943443453028747,
#    'loss': 0.046266757473830876,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58df970>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58e7130>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3798691685714023,
#    'loss': 0.04794085684362735,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58e73a0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58e78e0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3873496802195442,
#    'loss': 0.04708272139081532,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58ee2e0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58ee310>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.39086969337987654,
#    'loss': 0.04533469828398923,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58ee850>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58f8280>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.39404074721426974,
#    'loss': 0.04592289206779277,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58f8790>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58f87c0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.40219683995709243,
#    'loss': 0.04350582700658732,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d587f1f0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d587f700>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4052292775460812,
#    'loss': 0.04190347923900392,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d587f730>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d5881160>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4095969645450269,
#    'loss': 0.03501447570443046,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d5881430>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58816a0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4182914148000316,
#    'loss': 0.02568984858246615,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58850d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58853a0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4265862060802623,
#    'loss': 0.015613407802622497,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d5885610>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d5885bb0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4609874164469874,
#    'loss': 0.013774624691622646,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d5892550>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d5892580>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4690658593309569,
#    'loss': 0.01082967827869624,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d5892b20>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d589b4c0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.48010553259920474,
#    'loss': 0.009427916284620636,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d589b4f0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d589ba90>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.48229840530995616,
#    'loss': 0.00899877578756057,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58a41c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58a4430>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.49038458070539936,
#    'loss': 0.008526687976578205,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d58a4970>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d58b0130>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0
>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57f02e0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.2972591377622116,
#    'loss': 0.007536432852516414,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57f0400>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57f0a90>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3081009660269852,
#    'loss': 0.00840135691207843,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57f21c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57f2430>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.31319671161360196,
#    'loss': 0.00821864744460424,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57f2970>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d577e370>}},
#  {'event': 'DOWN',
#   'data': {'direction': 'LEFT',
#    'j_feature': 0,
#    'threshold': 0.26952736702290236}},
#  {'event': 'UP'},
#  {'event': 'DOWN',
#   'data': {'direction': 'RIGHT',
#    'j_feature': 0,
#    'threshold': 0.26952736702290236}},
#  {'event': 'UP'},
#  {'event': 'UP'},
#  {'event': 'DOWN',
#   'data': {'direction': 'RIGHT',
#    'j_feature': 0,
#    'threshold': 0.49294258453830675}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.6714723446803862,
#    'loss': 0.0074917146374216545,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d577eb50>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d578b130>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.6744539121792827,
#    'loss': 0.00759140029330929,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d578b400>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d578b9a0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.6929841524116082,
#    'loss': 0.008040653352892191,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d5790100>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d5790370>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7064648012602672,
#    'loss': 0.00808629442944825,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57908b0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57812b0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.736302260057679,
#    'loss': 0.007564958032833748,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57812e0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d5781820>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7471480980206835,
#    'loss': 0.007566227423465681,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d579f250>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d579f5b0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.761303210061735,
#    'loss': 0.007585227867922241,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d579f6d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57a7100>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7959645717953931,
#    'loss': 0.00770459109001737,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57a7610>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57a7640>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8017954368459437,
#    'loss': 0.008476303884122275,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57b1040>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57b1340>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8061948378837509,
#    'loss': 0.008354667902909396,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57b15b0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57b1b50>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.828987953653682,
#    'loss': 0.00801847428484699,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57aa2b0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57aa520>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8360774398568327,
#    'loss': 0.008057210848731577,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d57aaac0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d5746430>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8519895735339525,
#    'loss': 0.007973753896279984,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d5746460>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d57469a0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8622679290823674,
#    'loss': 0.007893092228794977,
#    'poly_left': <equadratures.poly.Poly at 0x7ff0d574c3d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7ff0d574c400>}},
#  {'event': 'DOWN',
#   'data': {'direction': 'LEFT',
#    'j_feature': 0,
#    'threshold': 0.6714723446803862}},
#  {'event': 'UP'},
#  {'event': 'DOWN',
#   'data': {'direction': 'RIGHT',
#    'j_feature': 0,
#    'threshold': 0.6714723446803862}},
#  {'event': 'UP'},
#  {'event': 'UP'},
#  {'event': 'UP'}]

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.set(xlim=(0, 1), ylim=(-1.5, 1))
ax.scatter(X, y, s=100)

try_line = []
try_line.append(ax.axhline(1))

best_line = []
best_line.append(ax.axhline(1))

fixed_line = []
fixed_line.append(ax.axhline(1))

left_try_poly, = ax.plot([], [], lw=2, color="red")
right_try_poly, = ax.plot([], [], lw=2, color="red")

left_best_poly, = ax.plot([], [], lw=2, color="green")
right_best_poly, = ax.plot([], [], lw=2, color="green")

left_fixed_poly, = ax.plot([], [], lw=2, color="black")
right_fixed_poly, = ax.plot([], [], lw=2,color="black")

fixed_polys = []
splits = [0, 1]
dirs = []

def boundary(threshold, direction):
    if direction == "left":
        left = right = max([split for split in splits if split < threshold])
        return left
    elif direction == "right":
        right = right = min([split for split in splits if split > threshold])
        return right
n = 0
def animate(log):
    print(splits)
    global n
    if log["event"] == "UP":
        try:fixed_polys.pop()
        except:pass
        try:splits.pop()
        except:pass
        try:best_line[-1].remove()
        except:pass
        try:dirs.pop()
        except:pass
        
    if log["event"] == "DOWN":
        splits.append(log["data"]["threshold"])

        fixed_line.append(ax.axvline(log["data"]["threshold"], color='black'))
        
        if log["data"]["direction"] == "LEFT":
            fixed_polys.append(ax.plot(right_fixed_poly.get_xdata(),right_fixed_poly.get_ydata(),color="black"))
            right_fixed_poly.set_data(deepcopy(right_best_poly.get_xdata()), deepcopy(right_best_poly.get_ydata()))
            dirs.append("left")
            
        if log["data"]["direction"] == "RIGHT":
            fixed_polys.append(ax.plot(left_fixed_poly.get_xdata(),left_fixed_poly.get_ydata(),color="black"))
            left_fixed_poly.set_data(deepcopy(left_best_poly.get_xdata()), deepcopy(left_best_poly.get_ydata()))
            dirs.append("right")
            
    if log["event"] == "try_split":
        try_line[-1].remove()
        try_line.append(ax.axvline(log["data"]["threshold"], color='red'))
 
        x_test = np.reshape(np.linspace(boundary(log["data"]["threshold"], "left"), log["data"]["threshold"], 100), (100, 1))
        left_try_poly.set_data(x_test, log["data"]["poly_left"].get_polyfit(x_test))
                        
        x_test = np.reshape(np.linspace(log["data"]["threshold"], boundary(log["data"]["threshold"], "right"), 100), (100, 1))
        right_try_poly.set_data(x_test, log["data"]["poly_right"].get_polyfit(x_test))
        
        n+=1
    if log["event"] == "best_split":
        try:best_line[-1].remove()
        except:pass
        
        best_line.append(ax.axvline(log["data"]["threshold"], color='green'))
         
        x_test = np.reshape(np.linspace(boundary(log["data"]["threshold"], "left"), log["data"]["threshold"], 100), (100, 1))
        left_best_poly.set_data(x_test, log["data"]["poly_left"].get_polyfit(x_test))
                        
        x_test = np.reshape(np.linspace(log["data"]["threshold"], boundary(log["data"]["threshold"], "right"), 100), (100, 1))
        right_best_poly.set_data(x_test, log["data"]["poly_right"].get_polyfit(x_test))
        
        left_try_poly.set_data([],[])
        right_try_poly.set_data([],[])
        
        n+=1
    ax.set_title('Polynomials fit: ' + str(n))
    print(n)

anim = FuncAnimation(fig, animate, interval=duration * 1000 / len(tree.log) * 10, frames=tree.log)
HTML(anim.to_html5_video())
# Out:
# [0, 1]
# 1
# [0, 1]
# 2
# [0, 1]
# 3
# [0, 1]
# 4
# [0, 1]
# 5
# [0, 1]
# 6
# [0, 1]
# 7
# [0, 1]
# 8
# [0, 1]
# 9
# [0, 1]
# 10
# [0, 1]
# 11
# [0, 1]
# 12
# [0, 1]
# 13
# [0, 1]
# 14
# [0, 1]
# 15
# [0, 1]
# 16
# [0, 1]
# 17
# [0, 1]
# 18
# [0, 1]
# 19
# [0, 1]
# 20
# [0, 1]
# 21
# [0, 1]
# 22
# [0, 1]
# 23
# [0, 1]
# 24
# [0, 1]
# 25
# [0, 1]
# 26
# [0, 1]
# 27
# [0, 1]
# 28
# [0, 1]
# 29
# [0, 1]
# 30
# [0, 1]
# 31
# [0, 1]
# 32
# [0, 1]
# 33
# [0, 1]
# 34
# [0, 1]
# 35
# [0, 1]
# 36
# [0, 1]
# 37
# [0, 1]
# 38
# [0, 1]
# 39
# [0, 1]
# 40
# [0, 1]
# 41
# [0, 1]
# 42
# [0, 1]
# 43
# [0, 1]
# 44
# [0, 1]
# 45
# [0, 1]
# 46
# [0, 1]
# 47
# [0, 1]
# 48
# [0, 1]
# 49
# [0, 1]
# 50
# [0, 1]
# 51
# [0, 1]
# 52
# [0, 1]
# 53
# [0, 1]
# 54
# [0, 1]
# 55
# [0, 1]
# 56
# [0, 1]
# 57
# [0, 1]
# 58
# [0, 1]
# 59
# [0, 1]
# 60
# [0, 1]
# 61
# [0, 1]
# 62
# [0, 1]
# 62
# [0, 1, 0.49294258453830675]
# 63
# [0, 1, 0.49294258453830675]
# 64
# [0, 1, 0.49294258453830675]
# 65
# [0, 1, 0.49294258453830675]
# 66
# [0, 1, 0.49294258453830675]
# 67
# [0, 1, 0.49294258453830675]
# 68
# [0, 1, 0.49294258453830675]
# 69
# [0, 1, 0.49294258453830675]
# 70
# [0, 1, 0.49294258453830675]
# 70
# [0, 1, 0.49294258453830675, 0.26952736702290236]
# 70
# [0, 1, 0.49294258453830675]
# 70
# [0, 1, 0.49294258453830675, 0.26952736702290236]
# 70
# [0, 1, 0.49294258453830675]
# 70
# [0, 1]
# 70
# [0, 1, 0.49294258453830675]
# 71
# [0, 1, 0.49294258453830675]
# 72
# [0, 1, 0.49294258453830675]
# 73
# [0, 1, 0.49294258453830675]
# 74
# [0, 1, 0.49294258453830675]
# 75
# [0, 1, 0.49294258453830675]
# 76
# [0, 1, 0.49294258453830675]
# 77
# [0, 1, 0.49294258453830675]
# 78
# [0, 1, 0.49294258453830675]
# 79
# [0, 1, 0.49294258453830675]
# 80
# [0, 1, 0.49294258453830675]
# 81
# [0, 1, 0.49294258453830675]
# 82
# [0, 1, 0.49294258453830675]
# 83
# [0, 1, 0.49294258453830675]
# 84
# [0, 1, 0.49294258453830675]
# 84
# [0, 1, 0.49294258453830675, 0.6714723446803862]
# 84
# [0, 1, 0.49294258453830675]
# 84
# [0, 1, 0.49294258453830675, 0.6714723446803862]
# 84
# [0, 1, 0.49294258453830675]
# 84
# [0, 1]
# 84
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...
# [0]
# Traceback (most recent call last):
#   File "/home/barney/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py", line 196, in process
#     func(*args, **kwargs)
#   File "/home/barney/.local/lib/python3.8/site-packages/matplotlib/animation.py", line 951, in _start
#     self._init_draw()
#   File "/home/barney/.local/lib/python3.8/site-packages/matplotlib/animation.py", line 1743, in _init_draw
#     self._draw_frame(next(self.new_frame_seq()))
#   File "/home/barney/.local/lib/python3.8/site-packages/matplotlib/animation.py", line 1766, in _draw_frame
#     self._drawn_artists = self._func(framedata, *self._args)
#   File "<ipython-input-14-df5992f73df4>", line 83, in animate
#     x_test = np.reshape(np.linspace(log["data"]["threshold"], boundary(log["data"]["threshold"], "right"), 100), (100, 1))
#   File "<ipython-input-14-df5992f73df4>", line 32, in boundary
#     right = right = min([split for split in splits if split > threshold])
# ValueError: min() arg is an empty sequence
