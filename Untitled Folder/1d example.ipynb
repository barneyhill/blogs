# %%
import sys
from equadratures import polytree
import random
import numpy as np
import scipy.stats as st
import time
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib.lines as mlines
# %matplotlib inline
from copy import deepcopy

# %%
def f(x, noise):
    
    if noise:
        noise = 0.1 * st.norm.rvs(0, 1)
    else:
        noise = 0
    if x < 0.5:
        return 25*(x-0.25)**2 - 1.0625 + noise
    elif x > 0.5:
        return 25*(x-0.75)**2 - 1.0625 + noise
    
def sample():
    X, y = [], []
    for i in range(100):
        x = random.random()    
        X.append(np.array([x]))
        y.append(np.array([f(x, True)]))
    return np.array(X), np.array(y)

X, y = sample()
y = np.reshape(y, (y.shape[0], 1))

tree = polytree.PolyTree(min_samples_leaf=20, logging=True)
#tree = polytree.PolyTree(search="uniform", min_samples_leaf=20, logging=True)
start = time.time()
tree.fit(X, y)
duration = time.time() - start

# %%
tree.log
# Out:
# [{'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.30536724988884856,
#    'loss': 29.173221338828025,
#    'poly_left': <equadratures.poly.Poly at 0x7fc92681ae80>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc926823640>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3138853392879769,
#    'loss': 28.549496897169906,
#    'poly_left': <equadratures.poly.Poly at 0x7fc926823760>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9268370d0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.31513066305143156,
#    'loss': 28.11544952889523,
#    'poly_left': <equadratures.poly.Poly at 0x7fc926837490>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9268376d0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3157364684495968,
#    'loss': 27.390030610190415,
#    'poly_left': <equadratures.poly.Poly at 0x7fc92683e100>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc92683e3d0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3306372682284757,
#    'loss': 27.00254792012497,
#    'poly_left': <equadratures.poly.Poly at 0x7fc92683e640>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc926835040>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3317994619647481,
#    'loss': 26.609471638110737,
#    'poly_left': <equadratures.poly.Poly at 0x7fc926835340>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9268355b0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3390466964048504,
#    'loss': 26.27414802045676,
#    'poly_left': <equadratures.poly.Poly at 0x7fc926835b50>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247c22b0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3530796791840517,
#    'loss': 26.006003826728634,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247c2520>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247c2ac0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.35511062813889005,
#    'loss': 25.78264387725835,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247d61f0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247d6460>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3598229960028734,
#    'loss': 25.504823889948707,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247d69a0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247dd160>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.36153574852465653,
#    'loss': 25.31149635531665,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247dd3d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247dd910>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3670800576385461,
#    'loss': 25.627590011559672,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247e50d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247e5340>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3976008611802502,
#    'loss': 25.397342998337685,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247e5880>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247e32b0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4048721507442884,
#    'loss': 24.927175638822856,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247e35b0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247e3850>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4052712127918293,
#    'loss': 24.88936735645253,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247f5220>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247f54f0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4551529701777872,
#    'loss': 24.528620815643468,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247f5760>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247f9190>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4754402665746492,
#    'loss': 23.959253622550936,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9247f9460>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247f96d0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4834705077523337,
#    'loss': 23.334099798435535,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924780100>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247803d0>}},
#  {'event': 'try_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.4884827130400541,
#    'loss': 22.606006665320646,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924780640>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc924787040>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.5021240850456791,
#    'loss': 21.867936504384843,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924787340>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247875b0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.5128228018236493,
#    'loss': 21.436088696319867,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924787b50>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9247902b0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.5332235181252056,
#    'loss': 21.320785239039214,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924790520>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc924790ac0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.5416031848657343,
#    'loss': 21.25538218248101,
#    'poly_left': <equadratures.poly.Poly at 0x7fc92479e1c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc92479e490>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.54524494883647,
#    'loss': 21.10450051829371,
#    'poly_left': <equadratures.poly.Poly at 0x7fc92479e9a0>,
#    'poly_right': <equadratures.poly.Poly at 0x7f
split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8498093783731252,
#    'loss': 24.900236843506395,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246d6640>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246de070>}},
#  {'event': 'DOWN',
#   'data': {'direction': 'LEFT',
#    'j_feature': 0,
#    'threshold': 0.5976878471383624}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.30536724988884856,
#    'loss': 11.19164201572533,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246defd0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246e20d0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3138853392879769,
#    'loss': 10.949691818321668,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246e23a0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246e2610>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.31513066305143156,
#    'loss': 10.743133127426406,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246e2bb0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246ed310>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3157364684495968,
#    'loss': 10.56389364930262,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246ded00>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246de8e0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3306372682284757,
#    'loss': 10.381001973227292,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246eddf0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246f81c0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3317994619647481,
#    'loss': 10.208346545876143,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246f82e0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246f8910>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3390466964048504,
#    'loss': 10.067179946240119,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246fe0d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246fe340>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.3530796791840517,
#    'loss': 9.914883496209692,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246fe880>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246812b0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.35511062813889005,
#    'loss': 9.807046293123989,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246815b0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc924681850>}},
#  {'event': 'DOWN',
#   'data': {'direction': 'LEFT',
#    'j_feature': 0,
#    'threshold': 0.35511062813889005}},
#  {'event': 'UP'},
#  {'event': 'DOWN',
#   'data': {'direction': 'RIGHT',
#    'j_feature': 0,
#    'threshold': 0.35511062813889005}},
#  {'event': 'UP'},
#  {'event': 'UP'},
#  {'event': 'DOWN',
#   'data': {'direction': 'RIGHT',
#    'j_feature': 0,
#    'threshold': 0.5976878471383624}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7764667303479216,
#    'loss': 7.909709861607973,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924682490>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc924682220>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.777560427051353,
#    'loss': 7.482765116956015,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924692280>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc924692550>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7817929321380707,
#    'loss': 6.963987806653778,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246927c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc92469e1f0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7874996499700477,
#    'loss': 6.439385365390369,
#    'poly_left': <equadratures.poly.Poly at 0x7fc92469e4c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc92469e730>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7892127132116578,
#    'loss': 5.854605387233101,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246829d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc924682a60>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7929174249266339,
#    'loss': 5.269714073132572,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246a1400>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246a1520>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.7994592231560834,
#    'loss': 4.6682829777437025,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246a1ac0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246a62b0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8133462555979694,
#    'loss': 4.204877313741459,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246a6520>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246a6ac0>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8186107776244335,
#    'loss': 3.872105275816348,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246b81c0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246b8490>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8296020745931177,
#    'loss': 3.601158922416676,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246b89a0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246be160>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8407757046693101,
#    'loss': 3.368458105209988,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246be3d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246be910>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8444329588004463,
#    'loss': 3.2226197748828858,
#    'poly_left': <equadratures.poly.Poly at 0x7fc9246440d0>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc924644340>}},
#  {'event': 'best_split',
#   'data': {'j_feature': 0,
#    'threshold': 0.8498093783731252,
#    'loss': 3.0973664316529503,
#    'poly_left': <equadratures.poly.Poly at 0x7fc924644880>,
#    'poly_right': <equadratures.poly.Poly at 0x7fc9246482b0>}},
#  {'event': 'DOWN',
#   'data': {'direction': 'LEFT',
#    'j_feature': 0,
#    'threshold': 0.8498093783731252}},
#  {'event': 'UP'},
#  {'event': 'DOWN',
#   'data': {'direction': 'RIGHT',
#    'j_feature': 0,
#    'threshold': 0.8498093783731252}},
#  {'event': 'UP'},
#  {'event': 'UP'},
#  {'event': 'UP'}]

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.set(xlim=(0, 1), ylim=(-1.5, 1))
ax.scatter(X, y, s=100)

try_line = []
try_line.append(ax.axhline(1))

best_line = []
best_line.append(ax.axhline(1))

fixed_line = []
fixed_line.append(ax.axhline(1))

left_try_poly, = ax.plot([], [], lw=2, color="red")
right_try_poly, = ax.plot([], [], lw=2, color="red")

left_best_poly, = ax.plot([], [], lw=2, color="green")
right_best_poly, = ax.plot([], [], lw=2, color="green")

left_fixed_poly, = ax.plot([], [], lw=2, color="black")
right_fixed_poly, = ax.plot([], [], lw=2,color="black")

fixed_polys = []
splits = [0, 1]
dirs = []

def boundary(threshold, direction):
    if direction == "left":
        left = max([split for split in splits if split < threshold])
        return left
    elif direction == "right":
        right = min([split for split in splits if split > threshold])
        return right
n = 0
def animate(log):
    print(splits)
    global n
    if log["event"] == "UP":
        try:fixed_polys.pop()
        except:pass
        try:splits.pop()
        except:pass
        try:best_line[-1].remove()
        except:pass
        try:dirs.pop()
        except:pass
        
    if log["event"] == "DOWN":
        splits.append(log["data"]["threshold"])

        fixed_line.append(ax.axvline(log["data"]["threshold"], color='black'))
        
        if log["data"]["direction"] == "LEFT":
            fixed_polys.append(ax.plot(right_fixed_poly.get_xdata(),right_fixed_poly.get_ydata(),color="black"))
            right_fixed_poly.set_data(deepcopy(right_best_poly.get_xdata()), deepcopy(right_best_poly.get_ydata()))
            dirs.append("left")
            
        if log["data"]["direction"] == "RIGHT":
            fixed_polys.append(ax.plot(left_fixed_poly.get_xdata(),left_fixed_poly.get_ydata(),color="black"))
            left_fixed_poly.set_data(deepcopy(left_best_poly.get_xdata()), deepcopy(left_best_poly.get_ydata()))
            dirs.append("right")
            
    if log["event"] == "try_split":
        try_line[-1].remove()
        try_line.append(ax.axvline(log["data"]["threshold"], color='red'))
 
        x_test = np.reshape(np.linspace(boundary(log["data"]["threshold"], "left"), log["data"]["threshold"], 100), (100, 1))
        left_try_poly.set_data(x_test, log["data"]["poly_left"].get_polyfit(x_test))
                        
        x_test = np.reshape(np.linspace(log["data"]["threshold"], boundary(log["data"]["threshold"], "right"), 100), (100, 1))
        right_try_poly.set_data(x_test, log["data"]["poly_right"].get_polyfit(x_test))
        
        n+=1
    if log["event"] == "best_split":
        try:best_line[-1].remove()
        except:pass
        
        best_line.append(ax.axvline(log["data"]["threshold"], color='green'))
         
        x_test = np.reshape(np.linspace(boundary(log["data"]["threshold"], "left"), log["data"]["threshold"], 100), (100, 1))
        left_best_poly.set_data(x_test, log["data"]["poly_left"].get_polyfit(x_test))
                        
        x_test = np.reshape(np.linspace(log["data"]["threshold"], boundary(log["data"]["threshold"], "right"), 100), (100, 1))
        right_best_poly.set_data(x_test, log["data"]["poly_right"].get_polyfit(x_test))
        
        left_try_poly.set_data([],[])
        right_try_poly.set_data([],[])
        
        n+=1
    ax.set_title('Polynomials fit: ' + str(n))
    print(n)

anim = FuncAnimation(fig, animate, interval=duration * 1000 / len(tree.log) * 20, frames=tree.log)
HTML(anim.to_html5_video())
# Out:
# [0, 1]
# 1
# [0, 1]
# 2
# [0, 1]
# 3
