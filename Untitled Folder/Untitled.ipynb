# %%
import sys
from equadratures import polytree
import random
import numpy as np
import scipy.stats as st

# %%
def f(x1,x2):
    noise = 0.1 * st.norm.rvs(0, 1)
    return np.exp(-(x1**2 + x2**2) + noise)

def sample():
    X, y = [], []
    for i in range(100):
        x1, x2 = random.random(), random.random()        
        X.append(np.array([x1, x2]))
        y.append(np.array(f(x1, x2)))
    return np.array(X), np.array(y)

X, y = sample()
y = np.reshape(y, (y.shape[0], 1))

print(X.shape,y.shape)
tree = polytree.PolyTree()
tree.fit(X, y)

for poly in tree.get_polys():
    print(poly.get_mean_and_variance())
# Out:
# (100, 2) (100, 1)
# (2.27079457908753, 25.850700037912876)
# (0.7749751202951121, 7.511285198377462)
# (67.91005204254598, 172670.30224573577)
# (0.496324126302212, 0.045761837152757334)
# (0.1543443224879617, 1.0128232085718885)
# (0.7250606128656499, 1.2049942634971595)

# %%
tree.tree
# Out:
# {'name': 'node',
#  'index': 0,
#  'loss': 0.003083853224393447,
#  'poly': <equadratures.poly.Poly at 0x7f6f415b83d0>,
#  'n_samples': 100,
#  'j_feature': 1,
#  'threshold': 0.3840731004411765,
#  'children': {'left': {'name': 'node',
#    'index': 1,
#    'loss': 0.002300854181447608,
#    'poly': <equadratures.poly.Poly at 0x7f6eeff59760>,
#    'n_samples': 33,
#    'j_feature': 0,
#    'threshold': 0.6790650272374323,
#    'children': {'left': {'name': 'node',
#      'index': 3,
#      'loss': 2.0266713190197975e-05,
#      'poly': <equadratures.poly.Poly at 0x7f6eeff66f40>,
#      'data': (array([[0.21938339, 0.07651698],
#              [0.06563979, 0.31995272],
#              [0.43322338, 0.18030526],
#              [0.21568303, 0.25548872],
#              [0.40461386, 0.02786622],
#              [0.09490814, 0.09483035],
#              [0.36914385, 0.10501763],
#              [0.22740622, 0.00724287],
#              [0.16002516, 0.36095143],
#              [0.12441878, 0.16969101],
#              [0.48607984, 0.1189595 ],
#              [0.34818758, 0.26942317],
#              [0.33249792, 0.20229891],
#              [0.46725791, 0.33957806],
#              [0.67906503, 0.21169451],
#              [0.00302687, 0.3118934 ],
#              [0.19755782, 0.0918827 ]]),
#       array([[0.95134052],
#              [0.91758022],
#              [0.98528684],
#              [0.95193262],
#              [0.85768665],
#              [1.05320309],
#              [0.84247163],
#              [1.02877192],
#              [0.91640638],
#              [0.86994549],
#              [0.80211461],
#              [0.80303155],
#              [0.86470282],
#              [0.59469211],
#              [0.58807483],
#              [0.82098386],
#              [0.97200404]])),
#      'n_samples': 17,
#      'j_feature': None,
#      'threshold': None,
#      'children': {'left': None, 'right': None},
#      'depth': 2},
#     'right': {'name': 'node',
#      'index': 4,
#      'loss': 1.541918772775865e-29,
#      'poly': <equadratures.poly.Poly at 0x7f6eeff6f0d0>,
#      'data': (array([[0.84217334, 0.31644185],
#              [0.7571554 , 0.2590096 ],
#              [0.91993249, 0.26017225],
#              [0.90747553, 0.26055967],
#              [0.99558639, 0.01362978],
#              [0.87580325, 0.01761303],
#              [0.94994326, 0.0654954 ],
#              [0.92603547, 0.08025205],
#              [0.98212368, 0.04223169],
#              [0.69085523, 0.3840731 ],
#              [0.71167025, 0.30218085],
#              [0.79296769, 0.36134495],
#              [0.96993803, 0.21123626],
#              [0.98693515, 0.08290295],
#              [0.91160069, 0.17975197],
#              [0.7755671 , 0.07801037]]),
#       array([[0.64317478],
#              [0.57914476],
#              [0.42278468],
#              [0.37973641],
#              [0.34119051],
#              [0.51553487],
#              [0.3640728 ],
#              [0.46057865],
#              [0.38630181],
#              [0.53071719],
#              [0.62910562],
#              [0.49854245],
#              [0.35610043],
#              [0.42676901],
#              [0.40186072],
#              [0.49479448]])),
#      'n_samples': 16,
#      'j_feature': None,
#      'threshold': None,
#      'children': {'left': None, 'right': None},
#      'depth': 2}},
#    'depth': 1},
#   'right': {'name': 'node',
#    'index': 2,
#    'loss': 0.0017722247449998634,
#    'poly': <equadratures.poly.Poly at 0x7f6eeffb5d60>,
#    'n_samples': 67,
#    'j_feature': 0,
#    'threshold': 0.22368052522380766,
#    'children': {'left': {'name': 'node',
#      'index': 5,
#      'loss': 5.274377302789246e-26,
#      'poly': <equadratures.poly.Poly at 0x7f6eeff6fe20>,
#      'data': (array([[0.21909766, 0.76428652],
#              [0.11491995, 0.71647145],
#              [0.15509209, 0.61807804],
#              [0.17919184, 0.78864134],
#              [0.03692034, 0.38779387],
#              [0.10844308, 0.73948755],
#              [0.07495603, 0.6179031 ],
#              [0.01378117, 0.79900149],
#              [0.00559069, 0.65817375],
#              [0.2081691 , 0.99768358],
#              [0.10952385, 0.94765913],
#              [0.17229676, 0.39151218],
#              [0.17776837, 0.81450016],
#              [0.03128766, 0.72613261],
#              [0.22368053, 0.76036772],
#              [0.06264697, 0.87577633]]),
#       array([[0.48993123],
#              [0.58882152],
#              [0.59101412],
#              [0.43722337],
#              [0.75848877],
#              [0.59228239],
#              [0.61587684],
#              [0.47686939],
#              [0.73219036],
#              [0.35112083],
#              [0.48040464],
#              [0.95322264],
#              [0.59977896],
#              [0.59438564],
#              [0.6638276 ],
#              [0.47596376]])),
#      'n_samples': 16,
#      'j_feature': None,
#      'threshold': None,
#      'children': {'left': None, 'right': None},
#      'depth': 2},
#     'right': {'name': 'node',
#      'index': 6,
#      'loss': 0.0008872347768500386,
#      'poly': <equadratures.poly.Poly at 0x7f6eeffb9ca0>,
#      'n_samples': 51,
#      'j_feature': 0,
#      'threshold': 0.4263733420448421,
#      'children': {'left': {'name': 'node',
#        'index': 7,
#        'loss': 1.0032169080313112e-30,
#        'poly': <equadratures.poly.Poly at 0x7f6eeffc9b80>,
#        'data': (array([[0.25621926, 0.57116096],
#                [0.3906201 , 0.98695607],
#                [0.30224245, 0.94204283],
#                [0.25866515, 0.94619525],
#                [0.42637334, 0.74877248],
#                [0.42431993, 0.86285042],
#                [0.35169102, 0.49658456],
#                [0.36388957, 0.67024336],
#                [0.31789322, 0.4620507 ],
#                [0.41495391, 0.88434411],
#                [0.40321675, 0.83347494],
#                [0.244658  , 0.96540147],
#                [0.39244322, 0.50666156],
#                [0.2658212 , 0.49014887],
#                [0.27693226, 0.65659105],
#                [0.28459704, 0.62015366]]),
#         array([[0.64411337],
#                [0.32961227],
#                [0.34876878],
#                [0.45775983],
#                [0.57859309],
#                [0.42222452],
#                [0.63638703],
#                [0.60411777],
#                [0.65175072],
#                [0.35764021],
#                [0.43474777],
#                [0.40927769],
#                [0.58946538],
#                [0.7882556 ],
#                [0.57799478],
#                [0.66576425]])),
#        'n_samples': 16,
#        'j_feature': None,
#        'threshold': None,
#        'children': {'left': None, 'right': None},
#        'depth': 3},
#       'right': {'name': 'node',
#        'index': 8,
#        'loss': 0.00043141043826200776,
#        'poly': <equadratures.poly.Poly at 0x7f6eeff7eac0>,
#        'n_samples': 35,
#        'j_feature': 0,
#        'threshold': 0.6042414461120778,
#        'children': {'left': {'name': 'node',
#          'index': 9,
#          'loss': 9.881946544650907e-31,
#          'poly': <equadratures.poly.Poly at 0x7f6eefff6970>,
#          'data': (array([[0.55089619, 0.6877009 ],
#                  [0.5962326 , 0.87393676],
#                  [0.59517467, 0.6334971 ],
#                  [0.50407196, 0.46474862],
#                  [0.5405836 , 0.88176006],
#                  [0.57951757, 0.96159396],
#                  [0.54467789, 0.48760259],
#                  [0.43669267, 0.91081521],
#                  [0.57439655, 0.76242222],
#                  [0.59079358, 0.90483223],
#                  [0.53606593, 0.64910136],
#                  [0.60424145, 0.57711921],
#                  [0.43244053, 0.8883843 ],
#                  [0.49365988, 0.39669785],
#                  [0.47567361, 0.74358076],
#                  [0.51942333, 0.99923376]]),
#           array([[0.45609422],
#                  [0.31650941],
#                  [0.41500739],
#                  [0.57756009],
#                  [0.35729454],
#                  [0.28341273],
#                  [0.54863749],
#                  [0.39629795],
#                  [0.3478812 ],
#                  [0.3140393 ],
#                  [0.45366891],
#                  [0.49646556],
#                  [0.40941704],
#                  [0.64059863],
#                  [0.47394792],
#                  [0.26294401]])),
#          'n_samples': 16,
#          'j_feature': None,
#          'threshold': None,
#          'children': {'left': None, 'right': None},
#          'depth': 4},
#         'right': {'name': 'node',
#          'index': 10,
#          'loss': 7.92877653594917e-06,
#          'poly': <equadratures.poly.Poly at 0x7f6ef4623040>,
#          'data': (array([[0.94650413, 0.54173857],
#                  [0.93845959, 0.61171205],
#                  [0.9707882 , 0.40592204],
#                  [0.7943257 , 0.77764649],
#                  [0.73600345, 0.88817918],
#                  [0.93433308, 0.76495968],
#                  [0.99761057, 0.50582829],
#                  [0.62815972, 0.98217726],
#                  [0.78147867, 0.96365365],
#                  [0.85378244, 0.72152428],
#                  [0.70162929, 0.62995537],
#                  [0.62982133, 0.6660162 ],
#                  [0.8310891 , 0.73334073],
#                  [0.80897267, 0.76861774],
#                  [0.79945648, 0.5941956 ],
#                  [0.82502197, 0.71773745],
#                  [0.75933711, 0.6668586 ],
#                  [0.67843624, 0.69655713],
#                  [0.76480933, 0.77261535]]),
#           array([[0.33843569],
#                  [0.30024115],
#                  [0.36687144],
#                  [0.25619324],
#                  [0.24043009],
#                  [0.24433599],
#                  [0.2723114 ],
#                  [0.28128204],
#                  [0.2331623 ],
#                  [0.28103415],
#                  [0.40206581],
#                  [0.49958689],
#                  [0.27857757],
#                  [0.26029445],
#                  [0.44001097],
#                  [0.30430614],
#                  [0.33538999],
#                  [0.41740957],
#                  [0.2989961 ]])),
#          'n_samples': 19,
#          'j_feature': None,
#          'threshold': None,
#          'children': {'left': None, 'right': None},
#          'depth': 4}},
#        'depth': 3}},
#      'depth': 2}},
#    'depth': 1}},
#  'depth': 0}

# %%
tree.get_graphviz(['x1','x2'])
# Out:
# https://dreampuf.github.io/GraphvizOnline/#digraph%20g%20%7B%0A%09node%20%5Bheight%3D.1%20shape%3Drecord%5D%0A%09node%20%5Blabel%3D%22x2%20%3C%3D%200.4%5Cn%20n_samples%20%3D%20100%5Cn%20loss%20%3D%200.003084%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.46692988878251357%5C%5Cn%27%2C%20%27x2%20%3A%200.504692823464897%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node0%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node%20%5Blabel%3D%22x1%20%3C%3D%200.7%5Cn%20n_samples%20%3D%2033%5Cn%20loss%20%3D%200.002301%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.6715083326128%5C%5Cn%27%2C%20%27x2%20%3A%200.025087848905098645%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node1%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node0%20-%3E%20node1%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22%20n_samples%20%3D%2017%5Cn%20loss%20%3D%200.000020%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.1545079836057497%5C%5Cn%27%2C%20%27x2%20%3A%200.23323111017640144%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node3%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node1%20-%3E%20node3%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22%20n_samples%20%3D%2016%5Cn%20loss%20%3D%200.000000%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.12123817177632032%5C%5Cn%27%2C%20%27x2%20%3A%200.28056211612397225%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node4%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node1%20-%3E%20node4%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22x1%20%3C%3D%200.2%5Cn%20n_samples%20%3D%2067%5Cn%20loss%20%3D%200.001772%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.6316559813059605%5C%5Cn%27%2C%20%27x2%20%3A%200.32127420400089984%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node2%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node0%20-%3E%20node2%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22%20n_samples%20%3D%2016%5Cn%20loss%20%3D%200.000000%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.28565574996090726%5C%5Cn%27%2C%20%27x2%20%3A%200.02761494310208469%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node5%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node2%20-%3E%20node5%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22x1%20%3C%3D%200.4%5Cn%20n_samples%20%3D%2051%5Cn%20loss%20%3D%200.000887%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.446630811120424%5C%5Cn%27%2C%20%27x2%20%3A%200.5182316168520019%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node6%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node2%20-%3E%20node6%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22%20n_samples%20%3D%2016%5Cn%20loss%20%3D%200.000000%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.06334910880769241%5C%5Cn%27%2C%20%27x2%20%3A%200.6433888995549731%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node7%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node6%20-%3E%20node7%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22x1%20%3C%3D%200.6%5Cn%20n_samples%20%3D%2035%5Cn%20loss%20%3D%200.000431%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.20754428862478597%5C%5Cn%27%2C%20%27x2%20%3A%200.6622663561663217%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node8%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node6%20-%3E%20node8%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22%20n_samples%20%3D%2016%5Cn%20loss%20%3D%200.000000%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.2613149643393993%5C%5Cn%27%2C%20%27x2%20%3A%200.14157934102930064%5C%5Cn%27%5D%22%20shape%3Drectangle%5D%0A%09node9%20%5Bcolor%3Dblack%20fillcolor%3Dwhite%20fontcolor%3Dblack%20style%3Dfilled%5D%0A%09node8%20-%3E%20node9%20%5Blabel%3D%22%22%5D%0A%09node%20%5Blabel%3D%22%20n_samples%20%3D%2019%5Cn%20loss%20%3D%200.000008%5Cn%20sobol%20indices%3A%20%5B%27x1%20%3A%200.2119396439004592%5C%5Cn%27%2C%20%2 ...

# %%
def get_splits():
    def _search_tree(node, splits):
        
        if node["children"]["left"] == None and node["children"]["right"] == None:
            return splits
        
        splits.append({'depth': node['depth'], 'j_feature': node['j_feature'], 'split': node['threshold']})

        if node["children"]["left"] != None:
            polys = _search_tree(node["children"]["left"], splits)

        if node["children"]["right"] != None:
            polys = _search_tree(node["children"]["right"], splits)

        return splits

    return _search_tree(tree.tree, [])

splits = get_splits()
splits = sorted(splits, key=lambda k: k['depth']) 

print(splits)
# Out:
# [{'depth': 0, 'j_feature': 1, 'split': 0.29841335097091726}, {'depth': 1, 'j_feature': 1, 'split': 0.14520539889674644}, {'depth': 1, 'j_feature': 1, 'split': 0.45703012523991726}, {'depth': 2, 'j_feature': 1, 'split': 0.36249113158530333}, {'depth': 2, 'j_feature': 1, 'split': 0.7949599967734868}, {'depth': 3, 'j_feature': 1, 'split': 0.6312187570858926}, {'depth': 4, 'j_feature': 0, 'split': 0.5772108356690506}]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

x1 = np.linspace(0, 1, 20)
x2 = np.linspace(0, 1, 20)

X1, X2 = np.meshgrid(x1, x2)
Z = f(X1, X2)
plt.contourf(X1, X2, Z, 20, cmap='RdGy')
plt.colorbar();
plt.axvline(x=0.5, ymin=0, ymax=1)
